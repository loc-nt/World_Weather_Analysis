# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
cities
# Out:
# ['duku',
#  'jalu',
#  'sentyabrskiy',
#  'yamada',
#  'ushuaia',
#  'kavaratti',
#  'saskylakh',
#  'beaverton',
#  'kapaa',
#  'bredasdorp',
#  'rikitea',
#  'barahona',
#  'zhigansk',
#  'gabu',
#  'san rafael',
#  'bar harbor',
#  'georgetown',
#  'arlit',
#  'busselton',
#  'yatou',
#  'lebu',
#  'cape town',
#  'atuona',
#  'castro',
#  'grand river south east',
#  'puerto ayora',
#  'jamestown',
#  'severo-kurilsk',
#  'punta arenas',
#  'valdivia',
#  'yellowknife',
#  'avarua',
#  'katsuura',
#  'namatanai',
#  'carnarvon',
#  'geraldton',
#  'marsa matruh',
#  'tuktoyaktuk',
#  'taoudenni',
#  'taolanaro',
#  'torbay',
#  'nikolskoye',
#  'hunza',
#  'suez',
#  'leshukonskoye',
#  'san joaquin',
#  'eyl',
#  'aasiaat',
#  'vaitupu',
#  'meyungs',
#  'saint george',
#  'marzuq',
#  'ribeira grande',
#  'hobart',
#  'bad sachsa',
#  'lerwick',
#  'saint-georges',
#  'tura',
#  'barrow',
#  'mataura',
#  'saldanha',
#  'albany',
#  'bluff',
#  'tarudant',
#  'acapulco',
#  'constitucion',
#  'waddan',
#  'kuminskiy',
#  'fukue',
#  'lixourion',
#  'arraial do cabo',
#  'amderma',
#  'banepa',
#  'at-bashi',
#  'gat',
#  'narsaq',
#  'belushya guba',
#  'barentsburg',
#  'komsomolskiy',
#  'poum',
#  'port alfred',
#  'mahebourg',
#  'illoqqortoormiut',
#  'yarmouth',
#  'akyab',
#  'padang',
#  'ekhabi',
#  'tadine',
#  'severnoye',
#  'pampa',
#  'tsihombe',
#  'damghan',
#  'butaritari',
#  'codrington',
#  'stornoway',
#  'mehran',
#  'vestmannaeyjar',
#  'port lincoln',
#  'klaksvik',
#  'halifax',
#  'dikson',
#  'upernavik',
#  'san matias',
#  'santa rosa',
#  'linares',
#  'luderitz',
#  'flinders',
#  'thompson',
#  'byron bay',
#  'caloundra',
#  'balkhash',
#  'awjilah',
#  'kinshasa',
#  'hilo',
#  'pevek',
#  'mar del plata',
#  'cabo san lucas',
#  'provideniya',
#  'saint-augustin',
#  'asau',
#  'oistins',
#  'naze',
#  'kodinsk',
#  'kaduqli',
#  'samusu',
#  'dharchula',
#  'bonavista',
#  'vostok',
#  'kashan',
#  'villazon',
#  'marfino',
#  'monrovia',
#  'alofi',
#  'cap malheureux',
#  'rodrigues alves',
#  'eyrarbakki',
#  'vaini',
#  'new norfolk',
#  'paragominas',
#  'lata',
#  'saleaula',
#  'tezu',
#  'sebrovo',
#  'nossa senhora da gloria',
#  'lagoa',
#  'khatanga',
#  'bambous virieux',
#  'saint-philippe',
#  'umzimvubu',
#  'sao miguel do araguaia',
#  'abu samrah',
#  'ilhabela',
#  'viligili',
#  'talnakh',
#  'vila velha',
#  'iqaluit',
#  'caravelas',
#  'atambua',
#  'darya khan mari',
#  'souris',
#  'isangel',
#  'cabra',
#  'alice springs',
#  'ponta do sol',
#  'sumbe',
#  'kodiak',
#  'coquimbo',
#  'auki',
#  'alta floresta',
#  'impfondo',
#  'stokmarknes',
#  'faanui',
#  'mikkeli',
#  'knysna',
#  'bonthe',
#  'gorno-chuyskiy',
#  'victoria',
#  'phan rang',
#  'tiksi',
#  'olafsvik',
#  'dordrecht',
#  'hannibal',
#  'srednekolymsk',
#  'talara',
#  'bethel',
#  'sola',
#  'airai',
#  'teguise',
#  'savinka',
#  'chimbote',
#  'esperance',
#  'grindavik',
#  'vila do maio',
#  'port blair',
#  'bongandanga',
#  'touho',
#  'rockingham',
#  'saint-joseph',
#  'ojo de agua',
#  'kuche',
#  'mariinsk',
#  'xining',
#  'lasa',
#  'lompoc',
#  'havoysund',
#  'hasaki',
#  'bahar',
#  'satitoa',
#  'nizhneyansk',
#  'khanpur',
#  'kisangani',
#  'ahipara',
#  'ranong',
#  'turan',
#  'itupiranga',
#  'namibe',
#  'hermanus',
#  'sao filipe',
#  'qaanaaq',
#  'fort-shevchenko',
#  'boa vista',
#  'junction city',
#  'tunceli',
#  'basco',
#  'east london',
#  'jackson',
#  'nouadhibou',
#  'faya',
#  'skibbereen',
#  'monteagudo',
#  'hervey bay',
#  'pangkalanbuun',
#  'puri',
#  'nova olinda do norte',
#  'rurrenabaque',
#  'broome',
#  'jiaonan',
#  'vila franca do campo',
#  'darnah',
#  'port elizabeth',
#  'mitchell',
#  'sur',
#  'bilma',
#  'alamosa',
#  'owando',
#  'nanortalik',
#  'port augusta',
#  'kegayli',
#  'simao',
#  'freeport',
#  'aklavik',
#  'nicoya',
#  'sparks',
#  'bikaner',
#  'san francisco',
#  'clyde river',
#  'bengkulu',
#  'shuiji',
#  'tazmalt',
#  'lavrentiya',
#  'chimoio',
#  'gold coast',
#  'hovd',
#  'muros',
#  'leh',
#  'mys shmidta',
#  'erdenet',
#  'port hueneme',
#  'takoradi',
#  'chokurdakh',
#  'urdzhar',
#  'san policarpo',
#  'barra do garcas',
#  'quatre cocos',
#  'mwinilunga',
#  'mangan',
#  'huancavelica',
#  'platanos',
#  'gambela',
#  'hithadhoo',
#  'dicabisagan',
#  'kahone',
#  'berveni',
#  'inhambane',
#  'marang',
#  'les cayes',
#  'comodoro rivadavia',
#  'ilulissat',
#  'bowen',
#  'danielskuil',
#  'hvide sande',
#  'omurtag',
#  'ust-ordynskiy',
#  'garowe',
#  'ilebo',
#  'safranbolu',
#  'sucre',
#  'fort saint james',
#  'atar',
#  'kingman',
#  'winnemucca',
#  'kupang',
#  'mount isa',
#  'kenai',
#  'marsh harbour',
#  'zawiercie',
#  'sao joao da barra',
#  'temaraia',
#  'pangoa',
#  'hambantota',
#  'mahon',
#  'bandarbeyla',
#  'soure',
#  'ilula',
#  'westport',
#  'mayya',
#  'umm lajj',
#  'sedelnikovo',
#  'meulaboh',
#  'kaeo',
#  'te anau',
#  'karla',
#  'filingue',
#  'murgab',
#  'denpasar',
#  'sitka',
#  'nome',
#  'itaqui',
#  'hirara',
#  'neiafu',
#  'aykhal',
#  'zhoucun',
#  'qasigiannguit',
#  'beringovskiy',
#  'kyle of lochalsh',
#  'tautira',
#  'cap-aux-meules',
#  'manaus',
#  'mayachnyy',
#  'biak',
#  'xuddur',
#  'vardo',
#  'bada',
#  'riyadh',
#  'marsaxlokk',
#  'rocha',
#  'buraydah',
#  'seoul',
#  'poso',
#  'paramonga',
#  'chuy',
#  'koumra',
#  'galesong',
#  'ramanuj ganj',
#  'ussel',
#  'gladstone',
#  'muhos',
#  'fairbanks',
#  'isiro',
#  'dezhou',
#  'babu',
#  'malchin',
#  'tuatapere',
#  'jining',
#  'quetzaltepec',
#  'ola',
#  'san patricio',
#  'kavieng',
#  'achisay',
#  'uusikaupunki',
#  'leningradskiy',
#  'dunedin',
#  'turki',
#  'pangody',
#  'la romana',
#  'merrill',
#  'kaitangata',
#  'waipawa',
#  'kwinana',
#  'puerto princesa',
#  'kunnamangalam',
#  'tasiilaq',
#  'kununurra',
#  'sept-iles',
#  'petrozavodsk',
#  'nagua',
#  'rabo de peixe',
#  'verkhnevilyuysk',
#  'isla vista',
#  'belmonte',
#  'rio grande',
#  'coihaique',
#  'san pedro',
#  'tarauaca',
#  'hobyo',
#  'chelno-vershiny',
#  'cairns',
#  'uralets',
#  'plouzane',
#  'viedma',
#  'haines junction',
#  'muzhi',
#  'raga',
#  'hvammstangi',
#  'acarau',
#  'nantucket',
#  'nautla',
#  'vikulovo',
#  'henties bay',
#  'aden',
#  'mahibadhoo',
#  'san juan',
#  'sakakah',
#  'saint anthony',
#  'veraval',
#  'touros',
#  'kibungo',
#  'mandalon',
#  'tabulbah',
#  'sinnamary',
#  'shimoda',
#  'kosa',
#  'nabire',
#  'guerrero negro',
#  'katherine',
#  'trikerion',
#  'ohara',
#  'pemangkat',
#  'ust-kuyga',
#  'locri',
#  'jijiga',
#  'adrar',
#  'ust-maya',
#  'yerbogachen',
#  'labuhan',
#  'plyussa',
#  'calama',
#  'lima',
#  'san blas',
#  'svetlyy',
#  'ji-parana',
#  'lokoja',
#  'poddorye',
#  'playas',
#  'tabiauea',
#  'cayenne',
#  'mana',
#  'norman wells',
#  'alyangula',
#  'goderich',
#  'ladario',
#  'kiruna',
#  'ganganagar',
#  'solnechnyy',
#  'zyryanka',
#  'barinas',
#  'bloemhof',
#  'valleyview',
#  'katangli',
#  'obo',
#  'jiuquan',
#  'wembley',
#  'zachagansk',
#  'warmbad',
#  'port keats',
#  'mau',
#  'bilibino',
#  'panjakent',
#  'roma',
#  'pimentel',
#  'kutum',
#  'college',
#  'koutsouras',
#  'mehamn',
#  'thessalon',
#  'pitimbu',
#  'rayagada',
#  'ambulu',
#  'mustasaari',
#  'manzhouli',
#  'beloha',
#  'yuzhno-kurilsk',
#  'casambalangan',
#  'foz',
#  'gizo',
#  'merauke',
#  'bamnet narong',
#  'sydney',
#  'attawapiskat',
#  'newport',
#  'tandil',
#  'bargal',
#  'north bend',
#  'sungaipenuh',
#  'porto novo',
#  'kentau',
#  'sabang',
#  'ongandjera',
#  'palabuhanratu',
#  'kyaikkami',
#  'santa cruz',
#  'carthage',
#  'mayumba',
#  'ilmajoki',
#  'labutta',
#  'elat',
#  'ancud',
#  'xam nua',
#  'jinan',
#  'vanavara',
#  'san cristobal',
#  'businga',
#  'suzu',
#  'griffith',
#  'jabinyanah',
#  'cidreira',
#  'arica',
#  'harper',
#  'kamyshlov',
#  'ayagoz',
#  'bolgatanga',
#  'portland',
#  'mpika',
#  'kamenskoye',
#  'jaitaran',
#  'poronaysk',
#  'pangnirtung',
#  'kommunisticheskiy',
#  'miraflores',
#  'horodnytsya',
#  'ondjiva',
#  'boulder',
#  'buta',
#  'ken caryl',
#  'bethal',
#  'havre-saint-pierre',
#  'ternate',
#  'tumen',
#  'grafton',
#  'ordu',
#  'kursumlija',
#  'nago',
#  'sarany',
#  'karachi',
#  'ozgon',
#  'dingle',
#  'ijaki',
#  'fraserburgh',
#  'nata',
#  'sompeta',
#  'kieta',
#  'pisco',
#  'kahului',
#  'samalaeulu',
#  'agadir',
#  'karpuninskiy',
#  'ostrovnoy',
#  'gornopravdinsk',
#  'karkaralinsk',
#  'tumannyy',
#  'rehoboth',
#  'sarangani',
#  'bolungarvik',
#  'mongo',
#  'senador guiomard',
#  'palauig',
#  'nhulunbuy',
#  'nemuro',
#  'avera',
#  'maniwaki',
#  'jimo',
#  'jilib',
#  'a',
#  'cherskiy',
#  'lorengau',
#  'lisala',
#  'ust-tarka',
#  'poya',
#  'luanda',
#  'laguna',
#  'novobiryusinskiy',
#  'edd',
#  'sherman',
#  'forbes',
#  'kamaishi',
#  'port macquarie',
#  'hualmay',
#  'dawson creek',
#  'itarema',
#  'dillon',
#  'dzhebariki-khaya',
#  'marcona',
#  'miramar',
#  'kresttsy',
#  'launceston',
#  'yangambi',
#  'yar-sale',
#  'qui nhon',
#  'inongo',
#  'nyagan',
#  'longyearbyen',
#  'bonham',
#  'omboue',
#  'hamilton',
#  'kamyshevatskaya',
#  'praia da vitoria',
#  'kibala',
#  'cacheu',
#  'medvezhyegorsk',
#  'chamalieres',
#  'cockburn town',
#  'san ramon',
#  'miles city',
#  'moron',
#  'kopong',
#  'carutapera',
#  'ozernovskiy',
#  'virginia beach',
#  'minab',
#  'souillac']

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5dba396e4d6e0b1a7a9aa77c399dcb45

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities): # enumerate can retrieve both the index and values in a list

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # try-except rainfall:
        try:
            city_rainfall = city_weather["rain"]['3h']
        except KeyError:
            city_rainfall = 0
        # try-except snowfall:
        try:
            city_snowfall = city_weather["snow"]['3h']
        except KeyError:
            city_snowfall = 0
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Rain inches (last 3 hours)": city_rainfall,
                          "Snow inches (last 3 hours)": city_snowfall                          
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | duku
# Processing Record 2 of Set 1 | jalu
# Processing Record 3 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 1 | yamada
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | kavaratti
# Processing Record 7 of Set 1 | saskylakh
# Processing Record 8 of Set 1 | beaverton
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | barahona
# Processing Record 13 of Set 1 | zhigansk
# Processing Record 14 of Set 1 | gabu
# Processing Record 15 of Set 1 | san rafael
# Processing Record 16 of Set 1 | bar harbor
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | arlit
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | yatou
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | severo-kurilsk
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | valdivia
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | katsuura
# Processing Record 34 of Set 1 | namatanai
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | geraldton
# Processing Record 37 of Set 1 | marsa matruh
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | taoudenni
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | torbay
# Processing Record 42 of Set 1 | nikolskoye
# Processing Record 43 of Set 1 | hunza
# City not found. Skipping...
# Processing Record 44 of Set 1 | suez
# Processing Record 45 of Set 1 | leshukonskoye
# Processing Record 46 of Set 1 | san joaquin
# Processing Record 47 of Set 1 | eyl
# Processing Record 48 of Set 1 | aasiaat
# Processing Record 49 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 2 | saint george
# Processing Record 2 of Set 2 | marzuq
# Processing Record 3 of Set 2 | ribeira grande
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | bad sachsa
# Processing Record 6 of Set 2 | lerwick
# Processing Record 7 of Set 2 | saint-georges
# Processing Record 8 of Set 2 | tura
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | mataura
# Processing Record 11 of Set 2 | saldanha
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | bluff
# Processing Record 14 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 2 | acapulco
# Processing Record 16 of Set 2 | constitucion
# Processing Record 17 of Set 2 | waddan
# Processing Record 18 of Set 2 | kuminskiy
# Processing Record 19 of Set 2 | fukue
# Processing Record 20 of Set 2 | lixourion
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 2 | banepa
# Processing Record 24 of Set 2 | at-bashi
# Processing Record 25 of Set 2 | gat
# Processing Record 26 of Set 2 | narsaq
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 2 | komsomolskiy
# Processing Record 30 of Set 2 | poum
# Processing Record 31 of Set 2 | port alfred
# Processing Record 32 of Set 2 | mahebourg
# Processing Record 33 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 2 | yarmouth
# Processing Record 35 of Set 2 | akyab
# Processing Record 36 of Set 2 | padang
# Processing Record 37 of Set 2 | ekhabi
# Processing Record 38 of Set 2 | tadine
# Processing Record 39 of Set 2 | severnoye
# Processing Record 40 of Set 2 | pampa
# Processing Record 41 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 2 | damghan
# Processing Record 43 of Set 2 | butaritari
# Processing Record 44 of Set 2 | codrington
# Processing Record 45 of Set 2 | stornoway
# Processing Record 46 of Set 2 | mehran
# Processing Record 47 of Set 2 | vestmannaeyjar
# Processing Record 48 of Set 2 | port lincoln
# Processing Record 49 of Set 2 | klaksvik
# Processing Record 50 of Set 2 | halifax
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | upernavik
# Processing Record 3 of Set 3 | san matias
# Processing Record 4 of Set 3 | santa rosa
# Processing Record 5 of Set 3 | linares
# Processing Record 6 of Set 3 | luderitz
# Processing Record 7 of Set 3 | flinders
# Processing Record 8 of Set 3 | thompson
# Processing Record 9 of Set 3 | byron bay
# Processing Record 10 of Set 3 | caloundra
# Processing Record 11 of Set 3 | balkhash
# Processing Record 12 of Set 3 | awjilah
# Processing Record 13 of Set 3 | kinshasa
# Processing Record 14 of Set 3 | hilo
# Processing Record 15 of Set 3 | pevek
# Processing Record 16 of Set 3 | mar del plata
# Processing Record 17 of Set 3 | cabo san lucas
# Processing Record 18 of Set 3 | provideniya
# Processing Record 19 of Set 3 | saint-augustin
# Processing Record 20 of Set 3 | asau
# Processing Record 21 of Set 3 | oistins
# Processing Record 22 of Set 3 | naze
# Processing Record 23 of Set 3 | kodinsk
# Processing Record 24 of Set 3 | kaduqli
# Processing Record 25 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 3 | dharchula
# Processing Record 27 of Set 3 | bonavista
# Processing Record 28 of Set 3 | vostok
# Processing Record 29 of Set 3 | kashan
# Processing Record 30 of Set 3 | villazon
# Processing Record 31 of Set 3 | marfino
# Processing Record 32 of Set 3 | monrovia
# Processing Record 33 of Set 3 | alofi
# Processing Record 34 of Set 3 | cap malheureux
# Processing Record 35 of Set 3 | rodrigues alves
# Processing Record 36 of Set 3 | eyrarbakki
# Processing Record 37 of Set 3 | vaini
# Processing Record 38 of Set 3 | new norfolk
# Processing Record 39 of Set 3 | paragominas
# Processing Record 40 of Set 3 | lata
# Processing Record 41 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 3 | tezu
# Processing Record 43 of Set 3 | sebrovo
# Processing Record 44 of Set 3 | nossa senhora da gloria
# Processing Record 45 of Set 3 | lagoa
# Processing Record 46 of Set 3 | khatanga
# Processing Record 47 of Set 3 | bambous virieux
# Processing Record 48 of Set 3 | saint-philippe
# Processing Record 49 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 3 | sao miguel do araguaia
# Processing Record 1 of Set 4 | abu samrah
# Processing Record 2 of Set 4 | ilhabela
# Processing Record 3 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 4 | talnakh
# Processing Record 5 of Set 4 | vila velha
# Processing Record 6 of Set 4 | iqaluit
# Processing Record 7 of Set 4 | caravelas
# Processing Record 8 of Set 4 | atambua
# Processing Record 9 of Set 4 | darya khan mari
# City not found. Skipping...
# Processing Record 10 of Set 4 | souris
# Processing Record 11 of Set 4 | isangel
# Processing Record 12 of Set 4 | cabra
# Processing Record 13 of Set 4 | alice springs
# Processing Record 14 of Set 4 | ponta do sol
# Processing Record 15 of Set 4 | sumbe
# Processing Record 16 of Set 4 | kodiak
# Processing Record 17 of Set 4 | coquimbo
# Processing Record 18 of Set 4 | auki
# Processing Record 19 of Set 4 | alta floresta
# Processing Record 20 of Set 4 | impfondo
# Processing Record 21 of Set 4 | stokmarknes
# Processing Record 22 of Set 4 | faanui
# Processing Record 23 of Set 4 | mikkeli
# Processing Record 24 of Set 4 | knysna
# Processing Record 25 of Set 4 | bonthe
# Processing Record 26 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 27 of Set 4 | victoria
# Processing Record 28 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 29 of Set 4 | tiksi
# Processing Record 30 of Set 4 | olafsvik
# Processing Record 31 of Set 4 | dordrecht
# Processing Record 32 of Set 4 | hannibal
# Processing Record 33 of Set 4 | srednekolymsk
# Processing Record 34 of Set 4 | talara
# Processing Record 35 of Set 4 | bethel
# Processing Record 36 of Set 4 | sola
# Processing Record 37 of Set 4 | airai
# Processing Record 38 of Set 4 | teguise
# Processing Record 39 of Set 4 | savinka
# Processing Record 40 of Set 4 | chimbote
# Processing Record 41 of Set 4 | esperance
# Processing Record 42 of Set 4 | grindavik
# Processing Record 43 of Set 4 | vila do maio
# Processing Record 44 of Set 4 | port blair
# Processing Record 45 of Set 4 | bongandanga
# Processing Record 46 of Set 4 | touho
# Processing Record 47 of Set 4 | rockingham
# Processing Record 48 of Set 4 | saint-joseph
# Processing Record 49 of Set 4 | ojo de agua
# Processing Record 50 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 5 | mariinsk
# Processing Record 2 of Set 5 | xining
# Processing Record 3 of Set 5 | lasa
# Processing Record 4 of Set 5 | lompoc
# Processing Record 5 of Set 5 | havoysund
# Processing Record 6 of Set 5 | hasaki
# Processing Record 7 of Set 5 | bahar
# Processing Record 8 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 5 | khanpur
# Processing Record 11 of Set 5 | kisangani
# Processing Record 12 of Set 5 | ahipara
# Processing Record 13 of Set 5 | ranong
# Processing Record 14 of Set 5 | turan
# Processing Record 15 of Set 5 | itupiranga
# Processing Record 16 of Set 5 | namibe
# Processing Record 17 of Set 5 | hermanus
# Processing Record 18 of Set 5 | sao filipe
# Processing Record 19 of Set 5 | qaanaaq
# Processing Record 20 of Set 5 | fort-shevchenko
# Processing Record 21 of Set 5 | boa vista
# Processing Record 22 of Set 5 | junction city
# Processing Record 23 of Set 5 | tunceli
# Processing Record 24 of Set 5 | basco
# Processing Record 25 of Set 5 | east london
# Processing Record 26 of Set 5 | jackson
# Processing Record 27 of Set 5 | nouadhibou
# Processing Record 28 of Set 5 | faya
# Processing Record 29 of Set 5 | skibbereen
# Processing Record 30 of Set 5 | monteagudo
# Processing Record 31 of Set 5 | hervey bay
# Processing Record 32 of Set 5 | pangkalanbuun
# Processing Record 33 of Set 5 | puri
# Processing Record 34 of Set 5 | nova olinda do norte
# Processing Record 35 of Set 5 | rurrenabaque
# Processing Record 36 of Set 5 | broome
# Processing Record 37 of Set 5 | jiaonan
# Processing Record 38 of Set 5 | vila franca do campo
# Processing Record 39 of Set 5 | darnah
# Processing Record 40 of Set 5 | port elizabeth
# Processing Record 41 of Set 5 | mitchell
# Processing Record 42 of Set 5 | sur
# Processing Record 43 of Set 5 | bilma
# Processing Record 44 of Set 5 | alamosa
# Processing Record 45 of Set 5 | owando
# Processing Record 46 of Set 5 | nanortalik
# Processing Record 47 of Set 5 | port augusta
# Processing Record 48 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 49 of Set 5 | simao
# Processing Record 50 of Set 5 | freeport
# Processing Record 1 of Set 6 | aklavik
# Processing Record 2 of Set 6 | nicoya
# Processing Record 3 of Set 6 | sparks
# Processing Record 4 of Set 6 | bikaner
# Processing Record 5 of Set 6 | san francisco
# Processing Record 6 of Set 6 | clyde river
# Processing Record 7 of Set 6 | bengkulu
# Processing Record 8 of Set 6 | shuiji
# Processing Record 9 of Set 6 | tazmalt
# Processing Record 10 of Set 6 | lavrentiya
# Processing Record 11 of Set 6 | chimoio
# Processing Record 12 of Set 6 | gold coast
# Processing Record 13 of Set 6 | hovd
# Processing Record 14 of Set 6 | muros
# Processing Record 15 of Set 6 | leh
# Processing Record 16 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 6 | erdenet
# Processing Record 18 of Set 6 | port hueneme
# Processing Record 19 of Set 6 | takoradi
# Processing Record 20 of Set 6 | chokurdakh
# Processing Record 21 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 22 of Set 6 | san policarpo
# Processing Record 23 of Set 6 | barra do garcas
# Processing Record 24 of Set 6 | quatre cocos
# Processing Record 25 of Set 6 | mwinilunga
# Processing Record 26 of Set 6 | mangan
# Processing Record 27 of Set 6 | huancavelica
# Processing Record 28 of Set 6 | platanos
# Processing Record 29 of Set 6 | gambela
# Processing Record 30 of Set 6 | hithadhoo
# Processing Record 31 of Set 6 | dicabisagan
# Processing Record 32 of Set 6 | kahone
# Processing Record 33 of Set 6 | berveni
# Processing Record 34 of Set 6 | inhambane
# Processing Record 35 of Set 6 | marang
# Processing Record 36 of Set 6 | les cayes
# Processing Record 37 of Set 6 | comodoro rivadavia
# Processing Record 38 of Set 6 | ilulissat
# Processing Record 39 of Set 6 | bowen
# Processing Record 40 of Set 6 | danielskuil
# Processing Record 41 of Set 6 | hvide sande
# Processing Record 42 of Set 6 | omurtag
# Processing Record 43 of Set 6 | ust-ordynskiy
# Processing Record 44 of Set 6 | garowe
# Processing Record 45 of Set 6 | ilebo
# Processing Record 46 of Set 6 | safranbolu
# Processing Record 47 of Set 6 | sucre
# Processing Record 48 of Set 6 | fort saint james
# Processing Record 49 of Set 6 | atar
# Processing Record 50 of Set 6 | kingman
# Processing Record 1 of Set 7 | winnemucca
# Processing Record 2 of Set 7 | kupang
# Processing Record 3 of Set 7 | mount isa
# Processing Record 4 of Set 7 | kenai
# Processing Record 5 of Set 7 | marsh harbour
# Processing Record 6 of Set 7 | zawiercie
# Processing Record 7 of Set 7 | sao joao da barra
# Processing Record 8 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 9 of Set 7 | pangoa
# Processing Record 10 of Set 7 | hambantota
# Processing Record 11 of Set 7 | mahon
# Processing Record 12 of Set 7 | bandarbeyla
# Processing Record 13 of Set 7 | soure
# Processing Record 14 of Set 7 | ilula
# Processing Record 15 of Set 7 | westport
# Processing Record 16 of Set 7 | mayya
# Processing Record 17 of Set 7 | umm lajj
# Processing Record 18 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 19 of Set 7 | meulaboh
# Processing Record 20 of Set 7 | kaeo
# Processing Record 21 of Set 7 | te anau
# Processing Record 22 of Set 7 | karla
# Processing Record 23 of Set 7 | filingue
# Processing Record 24 of Set 7 | murgab
# Processing Record 25 of Set 7 | denpasar
# Processing Record 26 of Set 7 | sitka
# Processing Record 27 of Set 7 | nome
# Processing Record 28 of Set 7 | itaqui
# Processing Record 29 of Set 7 | hirara
# Processing Record 30 of Set 7 | neiafu
# Processing Record 31 of Set 7 | aykhal
# Processing Record 32 of Set 7 | zhoucun
# Processing Record 33 of Set 7 | qasigiannguit
# Processing Record 34 of Set 7 | beringovskiy
# Processing Record 35 of Set 7 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 36 of Set 7 | tautira
# Processing Record 37 of Set 7 | cap-aux-meules
# Processing Record 38 of Set 7 | manaus
# Processing Record 39 of Set 7 | mayachnyy
# Processing Record 40 of Set 7 | biak
# Processing Record 41 of Set 7 | xuddur
# Processing Record 42 of Set 7 | vardo
# Processing Record 43 of Set 7 | bada
# Processing Record 44 of Set 7 | riyadh
# Processing Record 45 of Set 7 | marsaxlokk
# Processing Record 46 of Set 7 | rocha
# Processing Record 47 of Set 7 | buraydah
# Processing Record 48 of Set 7 | seoul
# Processing Record 49 of Set 7 | poso
# Processing Record 50 of Set 7 | paramonga
# Processing Record 1 of Set 8 | chuy
# Processing Record 2 of Set 8 | koumra
# Processing Record 3 of Set 8 | galesong
# Processing Record 4 of Set 8 | ramanuj ganj
# Processing Record 5 of Set 8 | ussel
# Processing Record 6 of Set 8 | gladstone
# Processing Record 7 of Set 8 | muhos
# Processing Record 8 of Set 8 | fairbanks
# Processing Record 9 of Set 8 | isiro
# Processing Record 10 of Set 8 | dezhou
# Processing Record 11 of Set 8 | babu
# Processing Record 12 of Set 8 | malchin
# Processing Record 13 of Set 8 | tuatapere
# Processing Record 14 of Set 8 | jining
# Processing Record 15 of Set 8 | quetzaltepec
# City not found. Skipping...
# Processing Record 16 of Set 8 | ola
# Processing Record 17 of Set 8 | san patricio
# Processing Record 18 of Set 8 | kavieng
# Processing Record 19 of Set 8 | achisay
# City not found. Skipping...
# Processing Record 20 of Set 8 | uusikaupunki
# Processing Record 21 of Set 8 | leningradskiy
# Processing Record 22 of Set 8 | dunedin
# Processing Record 23 of Set 8 | turki
# Processing Record 24 of Set 8 | pangody
# Processing Record 25 of Set 8 | la romana
# Processing Record 26 of Set 8 | merrill
# Processing Record 27 of Set 8 | kaitangata
# Processing Record 28 of Set 8 | waipawa
# Processing Record 29 of Set 8 | kwinana
# Processing Record 30 of Set 8 | puerto princesa
# Processing Record 31 of Set 8 | kunnamangalam
# Processing Record 32 of Set 8 | tasiilaq
# Processing Record 33 of Set 8 | kununurra
# Processing Record 34 of Set 8 | sept-iles
# Processing Record 35 of Set 8 | petrozavodsk
# Processing Record 36 of Set 8 | nagua
# Processing Record 37 of Set 8 | rabo de peixe
# Processing Record 38 of Set 8 | verkhnevilyuysk
# Processing Record 39 of Set 8 | isla vista
# Processing Record 40 of Set 8 | belmonte
# Processing Record 41 of Set 8 | rio grande
# Processing Record 42 of Set 8 | coihaique
# Processing Record 43 of Set 8 | san pedro
# Processing Record 44 of Set 8 | tarauaca
# Processing Record 45 of Set 8 | hobyo
# Processing Record 46 of Set 8 | chelno-vershiny
# Processing Record 47 of Set 8 | cairns
# Processing Record 48 of Set 8 | uralets
# Processing Record 49 of Set 8 | plouzane
# Processing Record 50 of Set 8 | viedma
# Processing Record 1 of Set 9 | haines junction
# Processing Record 2 of Set 9 | muzhi
# Processing Record 3 of Set 9 | raga
# Processing Record 4 of Set 9 | hvammstangi
# City not found. Skipping...
# Processing Record 5 of Set 9 | acarau
# Processing Record 6 of Set 9 | nantucket
# Processing Record 7 of Set 9 | nautla
# Processing Record 8 of Set 9 | vikulovo
# Processing Record 9 of Set 9 | henties bay
# Processing Record 10 of Set 9 | aden
# Processing Record 11 of Set 9 | mahibadhoo
# Processing Record 12 of Set 9 | san juan
# Processing Record 13 of Set 9 | sakakah
# Processing Record 14 of Set 9 | saint anthony
# Processing Record 15 of Set 9 | veraval
# Processing Record 16 of Set 9 | touros
# Processing Record 17 of Set 9 | kibungo
# Processing Record 18 of Set 9 | mandalon
# Processing Record 19 of Set 9 | tabulbah
# City not found. Skipping...
# Processing Record 20 of Set 9 | sinnamary
# Processing Record 21 of Set 9 | shimoda
# Processing Record 22 of Set 9 | kosa
# Processing Record 23 of Set 9 | nabire
# Processing Record 24 of Set 9 | guerrero negro
# Processing Record 25 of Set 9 | katherine
# Processing Record 26 of Set 9 | trikerion
# City not found. Skipping...
# Processing Record 27 of Set 9 | ohara
# Processing Record 28 of Set 9 | pemangkat
# Processing Record 29 of Set 9 | ust-kuyga
# Processing Record 30 of Set 9 | locri
# Processing Record 31 of Set 9 | jijiga
# Processing Record 32 of Set 9 | adrar
# Processing Record 33 of Set 9 | ust-maya
# Processing Record 34 of Set 9 | yerbogachen
# Processing Record 35 of Set 9 | labuhan
# Processing Record 36 of Set 9 | plyussa
# Processing Record 37 of Set 9 | calama
# Processing Record 38 of Set 9 | lima
# Processing Record 39 of Set 9 | san blas
# Processing Record 40 of Set 9 | svetlyy
# Processing Record 41 of Set 9 | ji-parana
# City not found. Skipping...
# Processing Record 42 of Set 9 | lokoja
# Processing Record 43 of Set 9 | poddorye
# Processing Record 44 of Set 9 | playas
# Processing Record 45 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 9 | cayenne
# Processing Record 47 of Set 9 | mana
# Processing Record 48 of Set 9 | norman wells
# Processing Record 49 of Set 9 | alyangula
# Processing Record 50 of Set 9 | goderich
# Processing Record 1 of Set 10 | ladario
# Processing Record 2 of Set 10 | kiruna
# Processing Record 3 of Set 10 | ganganagar
# Processing Record 4 of Set 10 | solnechnyy
# Processing Record 5 of Set 10 | zyryanka
# Processing Record 6 of Set 10 | barinas
# Processing Record 7 of Set 10 | bloemhof
# Processing Record 8 of Set 10 | valleyview
# Processing Record 9 of Set 10 | katangli
# Processing Record 10 of Set 10 | obo
# Processing Record 11 of Set 10 | jiuquan
# Processing Record 12 of Set 10 | wembley
# Processing Record 13 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 14 of Set 10 | warmbad
# Processing Record 15 of Set 10 | port keats
# Processing Record 16 of Set 10 | mau
# Processing Record 17 of Set 10 | bilibino
# Processing Record 18 of Set 10 | panjakent
# Processing Record 19 of Set 10 | roma
# Processing Record 20 of Set 10 | pimentel
# Processing Record 21 of Set 10 | kutum
# Processing Record 22 of Set 10 | college
# Processing Record 23 of Set 10 | koutsouras
# Processing Record 24 of Set 10 | mehamn
# Processing Record 25 of Set 10 | thessalon
# Processing Record 26 of Set 10 | pitimbu
# Processing Record 27 of Set 10 | rayagada
# Processing Record 28 of Set 10 | ambulu
# Processing Record 29 of Set 10 | mustasaari
# Processing Record 30 of Set 10 | manzhouli
# Processing Record 31 of Set 10 | beloha
# Processing Record 32 of Set 10 | yuzhno-kurilsk
# Processing Record 33 of Set 10 | casambalangan
# Processing Record 34 of Set 10 | foz
# Processing Record 35 of Set 10 | gizo
# Processing Record 36 of Set 10 | merauke
# Processing Record 37 of Set 10 | bamnet narong
# Processing Record 38 of Set 10 | sydney
# Processing Record 39 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 10 | newport
# Processing Record 41 of Set 10 | tandil
# Processing Record 42 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 10 | north bend
# Processing Record 44 of Set 10 | sungaipenuh
# Processing Record 45 of Set 10 | porto novo
# Processing Record 46 of Set 10 | kentau
# Processing Record 47 of Set 10 | sabang
# Processing Record 48 of Set 10 | ongandjera
# Processing Record 49 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 10 | kyaikkami
# Processing Record 1 of Set 11 | santa cruz
# Processing Record 2 of Set 11 | carthage
# Processing Record 3 of Set 11 | mayumba
# Processing Record 4 of Set 11 | ilmajoki
# Processing Record 5 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 11 | elat
# Processing Record 7 of Set 11 | ancud
# Processing Record 8 of Set 11 | xam nua
# Processing Record 9 of Set 11 | jinan
# Processing Record 10 of Set 11 | vanavara
# Processing Record 11 of Set 11 | san cristobal
# Processing Record 12 of Set 11 | businga
# Processing Record 13 of Set 11 | suzu
# City not found. Skipping...
# Processing Record 14 of Set 11 | griffith
# Processing Record 15 of Set 11 | jabinyanah
# Processing Record 16 of Set 11 | cidreira
# Processing Record 17 of Set 11 | arica
# Processing Record 18 of Set 11 | harper
# Processing Record 19 of Set 11 | kamyshlov
# Processing Record 20 of Set 11 | ayagoz
# Processing Record 21 of Set 11 | bolgatanga
# Processing Record 22 of Set 11 | portland
# Processing Record 23 of Set 11 | mpika
# Processing Record 24 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 11 | jaitaran
# Processing Record 26 of Set 11 | poronaysk
# Processing Record 27 of Set 11 | pangnirtung
# Processing Record 28 of Set 11 | kommunisticheskiy
# Processing Record 29 of Set 11 | miraflores
# Processing Record 30 of Set 11 | horodnytsya
# Processing Record 31 of Set 11 | ondjiva
# Processing Record 32 of Set 11 | boulder
# Processing Record 33 of Set 11 | buta
# Processing Record 34 of Set 11 | ken caryl
# Processing Record 35 of Set 11 | bethal
# Processing Record 36 of Set 11 | havre-saint-pierre
# Processing Record 37 of Set 11 | ternate
# Processing Record 38 of Set 11 | tumen
# Processing Record 39 of Set 11 | grafton
# Processing Record 40 of Set 11 | ordu
# Processing Record 41 of Set 11 | kursumlija
# Processing Record 42 of Set 11 | nago
# Processing Record 43 of Set 11 | sarany
# Processing Record 44 of Set 11 | karachi
# Processing Record 45 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 46 of Set 11 | dingle
# Processing Record 47 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 48 of Set 11 | fraserburgh
# Processing Record 49 of Set 11 | nata
# Processing Record 50 of Set 11 | sompeta
# Processing Record 1 of Set 12 | kieta
# Processing Record 2 of Set 12 | pisco
# Processing Record 3 of Set 12 | kahului
# Processing Record 4 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 12 | agadir
# Processing Record 6 of Set 12 | karpuninskiy
# City not found. Skipping...
# Processing Record 7 of Set 12 | ostrovnoy
# Processing Record 8 of Set 12 | gornopravdinsk
# Processing Record 9 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 10 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 12 | rehoboth
# Processing Record 12 of Set 12 | sarangani
# Processing Record 13 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 12 | mongo
# Processing Record 15 of Set 12 | senador guiomard
# Processing Record 16 of Set 12 | palauig
# Processing Record 17 of Set 12 | nhulunbuy
# Processing Record 18 of Set 12 | nemuro
# Processing Record 19 of Set 12 | avera
# Processing Record 20 of Set 12 | maniwaki
# Processing Record 21 of Set 12 | jimo
# Processing Record 22 of Set 12 | jilib
# Processing Record 23 of Set 12 | a
# City not found. Skipping...
# Processing Record 24 of Set 12 | cherskiy
# Processing Record 25 of Set 12 | lorengau
# Processing Record 26 of Set 12 | lisala
# Processing Record 27 of Set 12 | ust-tarka
# Processing Record 28 of Set 12 | poya
# Processing Record 29 of Set 12 | luanda
# Processing Record 30 of Set 12 | laguna
# Processing Record 31 of Set 12 | novobiryusinskiy
# Processing Record 32 of Set 12 | edd
# Processing Record 33 of Set 12 | sherman
# Processing Record 34 of Set 12 | forbes
# Processing Record 35 of Set 12 | kamaishi
# Processing Record 36 of Set 12 | port macquarie
# Processing Record 37 of Set 12 | hualmay
# Processing Record 38 of Set 12 | dawson creek
# Processing Record 39 of Set 12 | itarema
# Processing Record 40 of Set 12 | dillon
# Processing Record 41 of Set 12 | dzhebariki-khaya
# Processing Record 42 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 12 | miramar
# Processing Record 44 of Set 12 | kresttsy
# Processing Record 45 of Set 12 | launceston
# Processing Record 46 of Set 12 | yangambi
# Processing Record 47 of Set 12 | yar-sale
# Processing Record 48 of Set 12 | qui nhon
# Processing Record 49 of Set 12 | inongo
# Processing Record 50 of Set 12 | nyagan
# Processing Record 1 of Set 13 | longyearbyen
# Processing Record 2 of Set 13 | bonham
# Processing Record 3 of Set 13 | omboue
# Processing Record 4 of Set 13 | hamilton
# Processing Record 5 of Set 13 | kamyshevatskaya
# Processing Record 6 of Set 13 | praia da vitoria
# Processing Record 7 of Set 13 | kibala
# Processing Record 8 of Set 13 | cacheu
# Processing Record 9 of Set 13 | medvezhyegorsk
# Processing Record 10 of Set 13 | chamalieres
# Processing Record 11 of Set 13 | cockburn town
# Processing Record 12 of Set 13 | san ramon
# Processing Record 13 of Set 13 | miles city
# Processing Record 14 of Set 13 | moron
# Processing Record 15 of Set 13 | kopong
# Processing Record 16 of Set 13 | carutapera
# Processing Record 17 of Set 13 | ozernovskiy
# Processing Record 18 of Set 13 | virginia beach
# Processing Record 19 of Set 13 | minab
# Processing Record 20 of Set 13 | souillac
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data )
# Out:
# 569

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City Country                 Date    Lat     Lng  Max Temp  \
# 0              Duku      NG  2020-04-20 00:14:38  11.24    4.91     88.56
# 1              Jalu      LY  2020-04-20 00:14:38  29.03   21.55     71.15
# 2            Yamada      JP  2020-04-20 00:14:06  39.47  141.95     47.59
# 3           Ushuaia      AR  2020-04-20 00:13:00 -54.80  -68.30     41.00
# 4         Kavaratti      IN  2020-04-20 00:14:39  10.57   72.64     85.08
# ..              ...     ...                  ...    ...     ...       ...
# 564      Carutapera      BR  2020-04-20 00:17:26  -1.20  -46.02     79.54
# 565     Ozernovskiy      RU  2020-04-20 00:17:26  51.50  156.52     29.07
# 566  Virginia Beach      US  2020-04-20 00:16:35  36.85  -75.98     63.00
# 567           Minab      IR  2020-04-20 00:17:27  27.15   57.08     75.20
# 568        Souillac      MU  2020-04-20 00:17:27 -20.52   57.52     75.20
#
#      Humidity  Cloudiness  Wind Speed Current Description  \
# 0          43          63       10.07       broken clouds
# 1          24          38        8.03    scattered clouds
# 2          89         100        9.35          light rain
# 3          86          90       27.51     overcast clouds
# 4          69          42        5.19    scattered clouds
# ..        ...         ...         ...                 ...
# 564        85          59        8.99          light rain
# 565        89         100       10.29     overcast clouds
# 566        77          90        4.70     overcast clouds
# 567        83          90        2.24                mist
# 568        88          40       11.41    scattered clouds
#
#      Rain inches (last 3 hours)  Snow inches (last 3 hours)
# 0                          0.00                         0.0
# 1                          0.00                         0.0
# 2                          1.17                         0.0
# 3                          0.00                         0.0
# 4                          0.00                         0.0
# ..                          ...                         ...
# 564                        0.57                         0.0
# 565                        0.00                         0.0
# 566                        0.00                         0.0
# 567                        0.00                         0.0
# 568                        0.00                         0.0
#
# [569 rows x 12 columns]

# %%
# Create the output file (CSV).
output_data_file = "data\WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_df.dtypes
# Out:
# City                           object
# Country                        object
# Date                           object
# Lat                           float64
# Lng                           float64
# Max Temp                      float64
# Humidity                        int64
# Cloudiness                      int64
# Wind Speed                    float64
# Current Description            object
# Rain inches (last 3 hours)    float64
# Snow inches (last 3 hours)    float64
# dtype: object

# %%
# How many cities have recorded rainfall or snow?
a = city_data_df['Rain inches (last 3 hours)'] > 0
b = city_data_df['Snow inches (last 3 hours)'] > 0
count_loc = city_data_df.loc[a | b]
count_loc.count()

## There are 96 citites have recorded rainfall or snow
# Out:
# City                          96
# Country                       96
# Date                          96
# Lat                           96
# Lng                           96
# Max Temp                      96
# Humidity                      96
# Cloudiness                    96
# Wind Speed                    96
# Current Description           96
# Rain inches (last 3 hours)    96
# Snow inches (last 3 hours)    96
# dtype: int64
